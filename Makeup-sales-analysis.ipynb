# %% [markdown]
# # 💄✨ Makeup Sales Analysis Notebook
# ### 💖 Pink & Red Themed EDA

# %%
from IPython.display import HTMLHTML("""<style>body{font-family:Poppins;}.title{background:linear-gradient(90deg,#ff4d6d,#c9184a);padding:30px;border-radius:15px;color:white;font-size:40px;text-align:center;}.section{background:#c9184a;color:white;padding:12px;border-radius:10px;font-size:24px;margin-top:30px;}.box{background:#ffe5ec;border-left:8px solid #ff4d6d;padding:18px;border-radius:10px;color:#c9184a;}</style>""")

# %% [markdown]
# <div class='title'>💄 Makeup Sales Data Analysis</div>

# %%
import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport seaborn as snsimport plotly.express as pxsns.set_style("whitegrid")

# %% [markdown]
# <div class='section'>Load Dataset</div>

# %%
df = pd.read_csv("makeup_sales_dataset_2025.csv")df.head()

# %% [markdown]
# <div class='section'>Overview</div>

# %%
df.describe()

# %% [markdown]
# <div class='section'>Revenue Distribution</div>

# %%
sns.histplot(df['Revenue_USD'],kde=True,color='#ff4d6d')plt.show()

# %% [markdown]
# <div class='section'>Brand Analysis</div>

# %%
brand=df.groupby("Brand")["Revenue_USD"].sum()brand.plot(kind="bar",color="#c9184a")plt.show()

# %% [markdown]
# <div class='section'>Interactive Plot</div>

# %%
fig=px.scatter(df,x="Units_Sold",y="Revenue_USD",color_discrete_sequence=["#ff4d6d"])fig.show()
